# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('Demographic_Data.csv')

# %%
data.describe()
# Out:
#            in-store           age         items        amount        region
# count  80000.000000  80000.000000  80000.000000  80000.000000  80000.000000
# mean       0.500000     45.757925      4.504975    835.919670      2.675000
# std        0.500003     15.715679      2.061238    721.273736      1.126672
# min        0.000000     18.000000      1.000000      5.004700      1.000000
# 25%        0.000000     33.000000      3.000000    285.140000      2.000000
# 50%        0.500000     45.000000      4.000000    582.315000      3.000000
# 75%        1.000000     56.000000      6.000000   1233.700000      4.000000
# max        1.000000     85.000000      8.000000   3000.000000      4.000000

# %%
fig, axs = plt.subplots(1,5)
for i in range(5):
    axs[i].hist(data[data.columns.values[i]])
    axs[i].set_title(data.columns.values[i] + ' hist')
    axs[i].set_ylim(0,42000)
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=0.5, 
                    wspace=0.4, 
                    hspace=0.3)

# %%
binregionfreq = np.zeros(shape=(1,4))
binregion = np.zeros(shape=(1,4))
for i in range(4):
    binregionfreq[0][i]=sum(data['region']==(i+1))
    binregion[0][i]=i+1
plt.bar(binregion[0],binregionfreq[0])
plt.xlabel("Region", size = 14)
plt.ylabel('Frequency',size=14)
plt.xticks([1,2,3,4])
plt.show()

# %%
binitemfreq = np.zeros(shape=(1,8))
binitem = np.zeros(shape=(1,8))
for i in range(8):
    binitemfreq[0][i]=sum(data['items']==(i+1))
    binitem[0][i]=i+1
plt.bar(binitem[0],binitemfreq[0])
plt.xlabel("# items", size = 14)
plt.ylabel('Frequency',size=14)
plt.show()

# %%
plt.bar(['in-store','online'],[sum(data['in-store']),80000-sum(data['in-store'])])
plt.xlabel("Purchase type", size = 14)
plt.ylabel('#',size=14)
plt.show()

# %%
fig, ax = plt.subplots()
color=['tab:blue', 'tab:orange']
labs=['online','in-store']
for i in range(2):
    cosa=data.loc[data['in-store']==i,['age','amount']]
    ax.scatter(cosa.age, cosa.amount, c=color[i], alpha=0.02, edgecolors='none')
    ax.scatter([], [], c=color[i], alpha=0.8, label=labs[i])
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(1,2)
color=['tab:blue', 'tab:orange']
labs=['online','in-store']
for i in range(2):
    cosa=data.loc[data['in-store']==i,['age','amount']]
    ax[i].scatter(cosa.age, cosa.amount, c=color[i], alpha=0.05, edgecolors='none')
    ax[i].scatter([], [], c=color[i], label=labs[i])
    ax[i].legend(loc='upper right')
    ax[i].set_xlim(16,87)
    ax[i].set_ylim(0,3100)
    ax[i].set_xticks([18,25,35,45,55,65,75,85])
    ax[i].grid(color='black', linestyle = '--', linewidth = 0.5)
    ax[i].set_xlabel('age')
    ax[i].set_ylabel('amount')
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=1.1, 
                    wspace=0.5, 
                    hspace=0.5)
plt.show()

# %%
fig, ax = plt.subplots()
color=['tab:blue', 'tab:orange','tab:green','tab:red']
labs=['region 1','region 2','region 3','region 4']
for i in range(4):
    cosa=data.loc[data['region']==i+1,['age','amount']]
    ax.scatter(cosa.age, cosa.amount, c=color[i], alpha=0.02, edgecolors='none')
    ax.scatter([], [], c=color[i], alpha=0.6, label=labs[i])
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(1,4)
color=['tab:blue', 'tab:orange','tab:green','tab:red']
labs=['region 1','region 2','region 3','region 4']
for i in range(4):
    cosa=data.loc[data['region']==i+1,['age','amount']]
    ax[i].scatter(cosa.age, cosa.amount, c=color[i], alpha=0.05, edgecolors='none')
    ax[i].scatter([], [], c=color[i], label=labs[i])
    ax[i].legend(loc='upper right')
    ax[i].set_xlim(16,87)
    ax[i].set_ylim(0,3100)
    ax[i].set_xticks([18,25,35,45,55,65,75,85])
    ax[i].grid(color='black', linestyle = '--', linewidth = 0.5)
    ax[i].set_xlabel('age')
    ax[i].set_ylabel('amount')
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=0.7, 
                    wspace=0.3, 
                    hspace=0.5)
plt.show()

# %%
fig, axs = plt.subplots(5,5)
for i in range(5):
    for j in range(5):
        axs[i,j].scatter(data[data.columns.values[i]],data[data.columns.values[j]])
        axs[i,j].set_title(data.columns.values[i] + ' vs. ' + data.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
fig, axs = plt.subplots(1,5)
for i in range(5):
    axs[i].boxplot(data[data.columns.values[i]],0,'gD')
    axs[i].set_title(data.columns.values[i] + ' boxplot')
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=0.5, 
                    wspace=0.4, 
                    hspace=0.3)

# %%
corr_mat = data.corr()
print(corr_mat)
# Out:
#           in-store       age     items    amount    region
# in-store  1.000000 -0.178256 -0.003954 -0.085474 -0.133114
# age      -0.178256  1.000000  0.000679 -0.282089 -0.235446
# items    -0.003954  0.000679  1.000000  0.000367 -0.001925
# amount   -0.085474 -0.282089  0.000367  1.000000  0.403504
# region   -0.133114 -0.235446 -0.001925  0.403504  1.000000

# %%
datareg1=data.loc[data['region']==1,['in-store','age','items','amount']]

# %%
fig1, axs1 = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs1[i,j].scatter(datareg1[datareg1.columns.values[i]],datareg1[datareg1.columns.values[j]])
        axs1[i,j].set_title(datareg1.columns.values[i] + ' vs. ' + datareg1.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
datareg2=data.loc[data['region']==2,['in-store','age','items','amount']]

# %%
fig2, axs2 = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs2[i,j].scatter(datareg2[datareg2.columns.values[i]],datareg2[datareg2.columns.values[j]])
        axs2[i,j].set_title(datareg2.columns.values[i] + ' vs. ' + datareg2.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
datareg3=data.loc[data['region']==3,['in-store','age','items','amount']]

# %%
fig3, axs3 = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs3[i,j].scatter(datareg3[datareg3.columns.values[i]],datareg3[datareg3.columns.values[j]])
        axs3[i,j].set_title(datareg3.columns.values[i] + ' vs. ' + datareg3.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
datareg4=data.loc[data['region']==4,['in-store','age','items','amount']]

# %%
fig4, axs4 = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs4[i,j].scatter(datareg4[datareg4.columns.values[i]],datareg4[datareg4.columns.values[j]])
        axs4[i,j].set_title(datareg4.columns.values[i] + ' vs. ' + datareg4.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
dataage1=data.loc[data['age']<=25,['in-store','items','amount','region']]

# %%
fig, axs = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs[i,j].scatter(dataage1[dataage1.columns.values[i]],dataage1[dataage1.columns.values[j]])
        axs[i,j].set_title(dataage1.columns.values[i] + ' vs. ' + dataage1.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
prue=data.loc[data['age']>25,['in-store','age','items','amount','region']]
dataage2=prue.loc[data['age']<=35,['in-store','items','amount','region']]

# %%
fig, axs = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs[i,j].scatter(dataage2[dataage2.columns.values[i]],dataage2[dataage2.columns.values[j]])
        axs[i,j].set_title(dataage2.columns.values[i] + ' vs. ' + dataage2.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
prue=data.loc[data['age']>35,['in-store','age','items','amount','region']]
dataage3=prue.loc[data['age']<=45,['in-store','items','amount','region']]

# %%
fig, axs = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs[i,j].scatter(dataage3[dataage3.columns.values[i]],dataage3[dataage3.columns.values[j]])
        axs[i,j].set_title(dataage3.columns.values[i] + ' vs. ' + dataage3.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
prue=data.loc[data['age']>45,['in-store','age','items','amount','region']]
dataage4=prue.loc[data['age']<=55,['in-store','items','amount','region']]

# %%
fig, axs = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs[i,j].scatter(dataage4[dataage4.columns.values[i]],dataage4[dataage4.columns.values[j]])
        axs[i,j].set_title(dataage4.columns.values[i] + ' vs. ' + dataage4.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
prue=data.loc[data['age']>55,['in-store','age','items','amount','region']]
dataage5=prue.loc[data['age']<=65,['in-store','items','amount','region']]

# %%
fig, axs = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs[i,j].scatter(dataage5[dataage5.columns.values[i]],dataage5[dataage5.columns.values[j]])
        axs[i,j].set_title(dataage5.columns.values[i] + ' vs. ' + dataage5.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
prue=data.loc[data['age']>65,['in-store','age','items','amount','region']]
dataage6=prue.loc[data['age']<=75,['in-store','items','amount','region']]

# %%
fig, axs = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs[i,j].scatter(dataage6[dataage6.columns.values[i]],dataage6[dataage6.columns.values[j]])
        axs[i,j].set_title(dataage6.columns.values[i] + ' vs. ' + dataage6.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
dataage7=data.loc[data['age']>75,['in-store','items','amount','region']]

# %%
fig, axs = plt.subplots(4,4)
for i in range(4):
    for j in range(4):
        axs[i,j].scatter(dataage7[dataage7.columns.values[i]],dataage7[dataage7.columns.values[j]])
        axs[i,j].set_title(dataage7.columns.values[i] + ' vs. ' + dataage7.columns.values[j])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=2.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
corr_matage7 = dataage7.corr()
print(corr_matage7)
# Out:
#           in-store     items    amount  region
# in-store       NaN       NaN       NaN     NaN
# items          NaN  1.000000 -0.006994     NaN
# amount         NaN -0.006994  1.000000     NaN
# region         NaN       NaN       NaN     NaN

# %%
print(corr_matage7)
# Out:
#           in-store     items    amount  region
# in-store       NaN       NaN       NaN     NaN
# items          NaN  1.000000 -0.006994     NaN
# amount         NaN -0.006994  1.000000     NaN
# region         NaN       NaN       NaN     NaN

# %%
dataonline=data.loc[data['in-store']==0,['age','items','amount','region']]
datastore=data.loc[data['in-store']==1,['age','items','amount','region']]

# %%
fig, axs = plt.subplots(1,4)
for i in range(2):
    axs[i*2].hist(dataonline[dataonline.columns.values[i*2]])
    axs[2*i].set_title(dataonline.columns.values[i*2])
for i in range(2):
    x = np.zeros(shape=(1,-4*i+8))
    y = np.zeros(shape=(1,-4*i+8))
    for j in range(-4*i+8):
        x[0][j]=j+1
        y[0][j]=sum(dataonline[dataonline.columns.values[i*2+1]]==j+1)
    axs[i*2+1].bar(x[0],y[0])
    axs[2*i+1].set_title(dataonline.columns.values[i*2+1])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=0.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
fig, axs = plt.subplots(1,4)
for i in range(2):
    axs[i*2].hist(datastore[datastore.columns.values[i*2]])
    axs[2*i].set_title(datastore.columns.values[i*2])
for i in range(2):
    x = np.zeros(shape=(1,-4*i+8))
    y = np.zeros(shape=(1,-4*i+8))
    for j in range(-4*i+8):
        x[0][j]=j+1
        y[0][j]=sum(datastore[dataonline.columns.values[i*2+1]]==j+1)
    axs[i*2+1].bar(x[0],y[0])
    axs[2*i+1].set_title(datastore.columns.values[i*2+1])
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=0.7, 
                    wspace=0.3, 
                    hspace=0.5)

# %%
hist, bin_edges = np.histogram(data['in-store'], 2, range=(0, 2))
width = (bin_edges[1] - bin_edges[0])/2
plt.bar(bin_edges[:-1],hist, align='center', 
        width=width, edgecolor='k', facecolor='green', alpha=0.5)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar([0,1],[sum(data['in-store']==0),sum(data['in-store']==1)],align='center',width=0.5)
plt.xticks(range(2))
# Out:
# ([<matplotlib.axis.XTick at 0x1357c9bd1c0>,
# ...
#  [Text(0, 0, ''), Text(0, 0, '')])

# %%
histage,binsage = np.histogram(data['age'],bins = [18,25,35,45,55,65,75,85])

# %%
plt.hist(data['age'],[17.5,25.5,35.5,45.5,55.5,65.5,75.5,85.5],edgecolor='k', facecolor='green', alpha=0.6)
plt.xticks([18,25,35,45,55,65,75,85])
plt.show()

# %%
datareg1.describe()
# Out:
#        in-store           age         items        amount
# count   16000.0  16000.000000  16000.000000  16000.000000
# mean        1.0     43.703938      4.510063    745.161491
# std         0.0     14.084395      2.050344    493.131781
# min         1.0     19.000000      1.000000     50.050000
# 25%         1.0     32.000000      3.000000    359.012500
# 50%         1.0     43.000000      4.000000    662.920000
# 75%         1.0     53.000000      6.000000    973.632500
# max         1.0     74.000000      8.000000   1999.800000

# %%
datareg2.amount.mean()
# Out:
# 252.10919617500068

# %%
dataprueba=datareg4.loc[datareg4['in-store']==0,['age','items','amount']]
dataprueba.amount.mean()
# Out:
# 1543.7390553119535

# %%
sns.barplot(x='region',y='amount',data=data)
plt.show()

# %%
import matplotlib.patches as mpatches

# %%
sns.barplot(x='region',y='amount',hue='in-store',data=data)
plt.show()

# %%
sns.catplot(x="region", y="amount", hue="in-store", kind="bar", data=data)
plt.show()

# %%
sns.boxplot(x='region',y='amount',hue='in-store',data=data)
plt.show()

# %%
binsamount=np.array([0,500.5,1000.5,1500.5,2000.5,2500.5,3000.1])

# %%
binsages=np.array([17.9,25.1,35.1,45.1,55.1,65.1,75.1,85.1])

# %%
agrupamount = np.digitize(data.amount, binsamount)
namesamount=['0-500','501-1000','1001-1500','1501-2000','2001-2500','2501-3000']
pruebita=list()

# %%
agrupaages = np.digitize(data.age, binsages)
namesages=['18-25','26-35','36-45','46-55','56-65','66-75','76-85']
pruebita2=list()

# %%
for i in range(80000):
    pruebita.append(namesamount[agrupamount[i]-1])
    pruebita2.append(namesages[agrupaages[i]-1])

# %%
df=pd.DataFrame({'binsamount': pruebita},index=range(80000))
df2=pd.DataFrame({'binsages': pruebita2},index=range(80000))

# %%
data2=pd.concat([data,df],axis=1)
data2=pd.concat([data2,df2],axis=1)

# %%
fig, (axes1,axes2) = plt.subplots(1,2)
sns.countplot(x='region',hue='binsamount',data=data2,palette='Greens_d',ax=axes1)
sns.countplot(x='region',hue='binsages',data=data2,palette='Greens_d',ax=axes2)
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=0.7, 
                    wspace=0.3, 
                    hspace=0.5)
plt.show()

# %%
u=np.empty((7,4))
v=np.empty((7,4))
for i in range(4):
    f=dataage1.loc[dataage1['region']==i+1,['in-store','amount']]
    u[6,i]=round(f['amount'].mean(),1)
    v[6,i]=round(f['in-store'].mean(),2)
for i in range(4):
    f=dataage2.loc[dataage2['region']==i+1,['in-store','amount']]
    u[5,i]=round(f['amount'].mean(),1)
    v[5,i]=round(f['in-store'].mean(),2)
for i in range(4):
    f=dataage3.loc[dataage3['region']==i+1,['in-store','amount']]
    u[4,i]=round(f['amount'].mean(),1)
    v[4,i]=round(f['in-store'].mean(),2)
for i in range(4):
    f=dataage4.loc[dataage4['region']==i+1,['in-store','amount']]
    u[3,i]=round(f['amount'].mean(),1)
    v[3,i]=round(f['in-store'].mean(),2)
for i in range(4):
    f=dataage5.loc[dataage5['region']==i+1,['in-store','amount']]
    u[2,i]=round(f['amount'].mean(),1)
    v[2,i]=round(f['in-store'].mean(),2)
for i in range(4):
    f=dataage6.loc[dataage6['region']==i+1,['in-store','amount']]
    u[1,i]=round(f['amount'].mean(),1)
    v[1,i]=round(f['in-store'].mean(),2)
for i in range(4):
    f=dataage7.loc[dataage7['region']==i+1,['in-store','amount']]
    u[0,i]=round(f['amount'].mean(),1)
    v[0,i]=round(f['in-store'].mean(),2)

# %%
u
# Out:
# array([[   nan,  252.2,    nan,    nan],
#        [ 520.1,  255.2,  515.4,    nan],
#        [ 521.7,  251. ,  883.4, 1545.3],
#        [ 783. ,  253.9,  937.3, 1250.1],
#        [ 776.8,  249.2,  931.2, 1265.5],
#        [ 797.4,  250.9,  944.7, 1260.1],
#        [ 935.4,    nan, 1342.5, 1267.9]])

# %%
dataRAAmean=pd.DataFrame({'1':u[:,0],
                          '2':u[:,1],
                          '3':u[:,2],
                          '4':u[:,3]},
                        index=['[76-85]','[66-75]','[56-65]','[46-55]','[36-45]','[26-35]','[18-25]'])

# %%
dataRAImean=pd.DataFrame({'1':v[:,0],
                          '2':v[:,1],
                          '3':v[:,2],
                          '4':v[:,3]},
                        index=['[76-85]','[66-75]','[56-65]','[46-55]','[36-45]','[26-35]','[18-25]'])

# %%
dataRAAmean
# Out:
#              1      2       3       4
# [76-85]    NaN  252.2     NaN     NaN
# [66-75]  520.1  255.2   515.4     NaN
# [56-65]  521.7  251.0   883.4  1545.3
# [46-55]  783.0  253.9   937.3  1250.1
# [36-45]  776.8  249.2   931.2  1265.5
# [26-35]  797.4  250.9   944.7  1260.1
# [18-25]  935.4    NaN  1342.5  1267.9

# %%
mask = dataRAAmean.isnull()
fig, (ax1,ax2) = plt.subplots(1,2)
sns.heatmap(dataRAAmean,vmin=0,annot=True,cmap='Blues',fmt='1.1f',linewidths=.2,mask=mask, ax=ax1)
sns.heatmap(dataRAImean,vmin=0,annot=True,cmap='Greens',fmt='1.2f',linewidths=.2,mask=mask, ax=ax2)
ax1.set_xlabel('Region',size=14)
ax1.set_ylabel('Age',size=14)
ax2.set_xlabel('Region',size=14)
ax2.set_ylabel('Age',size=14)
plt.subplots_adjust(left=-1.2,
                    bottom=0.1, 
                    right=1.2, 
                    top=0.7, 
                    wspace=0.3, 
                    hspace=0.5)
plt.show()

# %%
data.tail()
# Out:
#        in-store  age  items   amount  region
# 79995         1   71      3   558.82       1
# 79996         0   59      7  1932.00       3
# 79997         0   54      1   414.16       2
# 79998         1   49      4   335.32       1
# 79999         1   30      1   527.12       3

# %%
d = dict(tuple(data.groupby("items")))
d
# Out:
# {1:        in-store  age  items    amount  region
#  34            1   55      1   120.470       3
#  38            0   43      1   472.690       2
#  43            0   44      1   861.210       3
#  55            1   26      1  1448.600       4
#  59            0   66      1    65.619       2
#  ...         ...  ...    ...       ...     ...
#  79981         0   38      1    63.839       2
#  79989         0   69      1   404.420       2
#  79994         0   22      1   698.540       4
#  79997         0   54      1   414.160       2
#  79999         1   30      1   527.120       3
#
#  [5701 rows x 5 columns],
#  2:        in-store  age  items     amount  region
#  1             0   35      2   219.5100       2
#  11            1   33      2   684.3200       1
#  12            0   32      2    58.9970       2
#  18            0   35      2  2791.6000       4
#  24            1   53      2   283.5000       4
#  ...         ...  ...    ...        ...     ...
# ...

# %%
for key in d.keys():
    d[key]

# %%
dir(d)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
f=d.keys()

# %%
d[2]
# Out:
#        in-store  age  items     amount  region
# 1             0   35      2   219.5100       2
# 11            1   33      2   684.3200       1
# 12            0   32      2    58.9970       2
# 18            0   35      2  2791.6000       4
# 24            1   53      2   283.5000       4
# ...         ...  ...    ...        ...     ...
# 79899         0   49      2  1067.2000       4
# 79905         0   62      2     6.9559       2
# 79922         0   55      2  2871.4000       3
# 79932         1   39      2   772.3400       3
# 79987         0   39      2   449.9400       2
#
# [11290 rows x 5 columns]

# %%
print(color.UNDERLINE + 'Hello World !' + color.END)
# Out:
# Hello World !

# %%
# Out:
# stat=24.588, p=0.265
# Probably independent

# %%
cont_tab_items_region = pd.crosstab(data['items'],data['region'],margins = False)
print(cont_tab_items_region)
# Out:
# region     1     2     3     4
# items
# 1       1106  1443  1260  1892
# 2       2222  2829  2576  3663
# 3       2317  2801  2599  3770
# 4       2390  2892  2675  3639
# 5       2241  2802  2513  3682
# 6       2358  2892  2515  3757
# 7       2181  2907  2568  3722
# 8       1185  1434  1294  1875

# %%
datp=data2.groupby('in-store')['in-store'].count()

# %%
datp[0]
# Out:
# 40000

# %%
for i in datp.index:
    print(i)
# Out:
# 0
# 1

# %%
fig = sns.FacetGrid(data, hue='in-store', aspect=4)
fig.map(sns.kdeplot, 'age', shade=True)
oldest = data['age'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Gender')
fig.add_legend(order=['1','0'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-bb8366b14a95> in <module>
#       4 fig.set(xlim=(0,oldest))
#       5 fig.set(title='Distribution of Age Grouped by Gender')
# ----> 6 fig.add_legend(order=['1','0'])
#       7 plt.show()
#
# ~\anaconda3\envs\DataScience\lib\site-packages\seaborn\axisgrid.py in add_legend(self, legend_data, title, label_order, adjust_subtitles, **kwargs)
#     130
#     131             # Draw a full-figure legend outside the grid
# --> 132             figlegend = self.fig.legend(handles, labels, **kwargs)
#     133
#     134             self._legend = figlegend
#
# ~\anaconda3\envs\DataScience\lib\site-packages\matplotlib\figure.py in legend(self, *args, **kwargs)
#    1956         transform = kwargs.pop('bbox_transform', self.transFigure)
#    1957         # explicitly set the bbox transform if the user hasn't.
# ...

# %%
sns.lmplot(x='age', y='in-store', data=data, hue='region')
